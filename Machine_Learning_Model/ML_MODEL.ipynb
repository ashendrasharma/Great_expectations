# %%
import pandas as pd
import pymongo
from pymongo import MongoClient

client = MongoClient('mongodb://intelliinvest:intelliinvest@67.211.219.52:27017/intelliinvest')
db = client['intelliinvest']
collection = db['STOCK_FUNDAMENTALS']

security_id = "INDIGOPNTS"
query = {"securityId": security_id}
results = collection.find(query).limit(5000)

TCS = pd.DataFrame(list(results))
TCS
# Out:
#                           _id  securityId           industry yearQuarter  \
# 0    661fd11fae4cb91426459207  INDIGOPNTS  Consumer Durables      2021Q1
# 1    661fd11fae4cb91426459208  INDIGOPNTS  Consumer Durables      2021Q1
# 2    661fd11fae4cb91426459209  INDIGOPNTS  Consumer Durables      2021Q1
# 3    661fd11fae4cb9142645920a  INDIGOPNTS  Consumer Durables      2021Q1
# 4    661fd11fae4cb9142645920b  INDIGOPNTS  Consumer Durables      2021Q1
# ..                        ...         ...                ...         ...
# 789  661fd11fae4cb9142645951c  INDIGOPNTS  Consumer Durables      2024Q2
# 790  661fd11fae4cb9142645951d  INDIGOPNTS  Consumer Durables      2024Q2
# 791  661fd11fae4cb9142645951e  INDIGOPNTS  Consumer Durables      2024Q2
# 792  661fd11fae4cb9142645951f  INDIGOPNTS  Consumer Durables      2024Q2
# 793  661fd11fae4cb91426459520  INDIGOPNTS  Consumer Durables      2024Q2
#
#      closePrice   alMarketCap  alBookValuePerShare  alEarningPerShare  \
# ...

# %%
collection = db['STOCK_SIGNALS_COMPONENTS_10']

security_id = "INDIGOPNTS"
query = {"securityId": security_id}

results = collection.find(query).limit(5000)
TCS_1 = pd.DataFrame(list(results))
TCS_1
# Out:
#                           _id  securityId      TR  plusDM1  minusDM1  \
# 0    661fcd09ae4cb914265193bc  INDIGOPNTS  690.13     0.00      0.00
# 1    661fcd09ae4cb914265193bd  INDIGOPNTS  496.68   200.14      0.00
# 2    661fcd09ae4cb914265193be  INDIGOPNTS  114.49     0.00      0.00
# 3    661fcd09ae4cb914265193bf  INDIGOPNTS  295.79     0.00    248.98
# 4    661fcd09ae4cb914265193c0  INDIGOPNTS  184.25     0.00     51.79
# ..                        ...         ...     ...      ...       ...
# 789  661fcd09ae4cb914265196d1  INDIGOPNTS   60.90     0.00     41.25
# 790  661fcd09ae4cb914265196d2  INDIGOPNTS   24.00     0.00      0.00
# 791  661fcd09ae4cb914265196d3  INDIGOPNTS   19.50     4.45      0.00
# 792  661fcd09ae4cb914265196d4  INDIGOPNTS   46.65     0.00     36.55
# 793  661fcd09ae4cb914265196d5  INDIGOPNTS   29.50     6.05      0.00
#
#              TRn     plusDMn    minusDMn    plusDIn   minusDIn  ...  \
# 0     690.130000    0.000000    0.000000   0.000000   0.000000  ...
# ...

# %%
TCS = TCS.rename(columns={'todayDate': 'signalDate'})

# %%
TCS['signalDate'] = pd.to_datetime(TCS['signalDate'])
TCS_1['signalDate'] = pd.to_datetime(TCS_1['signalDate'])

# %%
merged_data = pd.merge(TCS, TCS_1, on=['securityId', 'signalDate'], how='inner')

# %%
selected_columns = ['signalDate','yearQuarter', 'closePrice', 'securityId', 'TRn', 'ADXn', 'high10Day', 'low10Day', 'stochastic10Day', 'range10Day', 'percentKFlow', 'percentDFlow', 'upperBound', 'lowerBound', 'bandwidth', 'movingAverage_5', 'movingAverage_10', 'movingAverage_15', 'movingAverage_25', 'movingAverage_50']
df = merged_data[selected_columns]
df
# Out:
#              signalDate yearQuarter  closePrice  securityId          TRn  \
# 0   2021-02-01 18:30:00      2021Q1     3104.49  INDIGOPNTS   690.130000
# 1   2021-02-02 18:30:00      2021Q1     2912.37  INDIGOPNTS  1186.810000
# 2   2021-02-03 18:30:00      2021Q1     2862.08  INDIGOPNTS  1301.300000
# 3   2021-02-04 18:30:00      2021Q1     2619.37  INDIGOPNTS  1597.090000
# 4   2021-02-07 18:30:00      2021Q1     2666.18  INDIGOPNTS  1781.340000
# ..                  ...         ...         ...         ...          ...
# 789 2024-04-08 18:30:00      2024Q2     1329.00  INDIGOPNTS   408.165020
# 790 2024-04-09 18:30:00      2024Q2     1338.75  INDIGOPNTS   391.348518
# 791 2024-04-11 18:30:00      2024Q2     1347.80  INDIGOPNTS   371.713666
# 792 2024-04-14 18:30:00      2024Q2     1329.50  INDIGOPNTS   381.192300
# 793 2024-04-15 18:30:00      2024Q2     1321.20  INDIGOPNTS   372.573070
#
#            ADXn  high10Day  low10Day  stochastic10Day  range10Day  \
# ...

# %%
df['signalDate'] = pd.to_datetime(df['signalDate'])
# Out:
# /var/folders/q0/gxyt0md94t5g331cqsdw5w7m0000gn/T/ipykernel_2999/1399526314.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['signalDate'] = pd.to_datetime(df['signalDate'])

# %%
df['signalDate'] = pd.to_datetime(df['signalDate'])
df['signalDate'] = df['signalDate'].dt.date
print(df['signalDate'])
# Out:
# 0      2021-02-01
# 1      2021-02-02
# 2      2021-02-03
# 3      2021-02-04
# 4      2021-02-07
#           ...
# 789    2024-04-08
# 790    2024-04-09
# 791    2024-04-11
# 792    2024-04-14
# 793    2024-04-15
# Name: signalDate, Length: 794, dtype: object
# /var/folders/q0/gxyt0md94t5g331cqsdw5w7m0000gn/T/ipykernel_2999/1410270968.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['signalDate'] = pd.to_datetime(df['signalDate'])
# /var/folders/q0/gxyt0md94t5g331cqsdw5w7m0000gn/T/ipykernel_2999/1410270968.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df['signalDate'] = df['signalDate'].astype(str)
df['yearQuarter'] = df['yearQuarter'].astype(str)
# Out:
# /var/folders/q0/gxyt0md94t5g331cqsdw5w7m0000gn/T/ipykernel_2999/337504824.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['signalDate'] = df['signalDate'].astype(str)
# /var/folders/q0/gxyt0md94t5g331cqsdw5w7m0000gn/T/ipykernel_2999/337504824.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['yearQuarter'] = df['yearQuarter'].astype(str)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor, BaggingRegressor
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# %%
# Function to calculate RMSE
def calculate_rmse(true_values, predictions):
    return np.sqrt(mean_squared_error(true_values, predictions))

# %%
df['signalDate'] = pd.to_datetime(df['signalDate'])
# Out:
# /var/folders/q0/gxyt0md94t5g331cqsdw5w7m0000gn/T/ipykernel_2999/1399526314.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['signalDate'] = pd.to_datetime(df['signalDate'])

# %%
df = df.drop(columns=['yearQuarter', 'securityId'])

# %%
df = df.sort_values(by='signalDate')

# %%
validation_start_date = '2024-03-01'
validation_end_date = '2024-03-31'

# %%
train_df = df[df['signalDate'] < validation_start_date]
validation_df = df[(df['signalDate'] >= validation_start_date) & (df['signalDate'] <= validation_end_date)]

# %%
X_train = train_df.drop(columns=['closePrice'])
y_train = train_df['closePrice']
X_validation = validation_df.drop(columns=['closePrice'])
y_validation = validation_df['closePrice']

# %%
X_validation_with_date = X_validation.copy()
X_validation_with_date['signalDate'] = validation_df['signalDate']

# %%
# Define parameter grids for each model
param_grid_lr = {
    'n_estimators': [10, 50],
    'max_samples': [0.8, 1.0]
}

param_grid_dt = {
    'base_estimator__max_depth': [10, 20],
    'n_estimators': [10, 50],
    'max_samples': [0.8, 1.0]
}

param_grid_gb = {
    'base_estimator__n_estimators': [50, 100],
    'base_estimator__learning_rate': [0.01, 0.1],
    'n_estimators': [10, 50],
    'max_samples': [0.8, 1.0]
}

# %%
grid_lr = GridSearchCV(estimator=BaggingRegressor(base_estimator=Ridge(), random_state=42),
                       param_grid=param_grid_lr, cv=3, scoring='neg_mean_squared_error', n_jobs=-1)
grid_lr.fit(X_train.drop(columns=['signalDate']), y_train)

grid_dt = GridSearchCV(estimator=BaggingRegressor(base_estimator=DecisionTreeRegressor(), random_state=42),
                       param_grid=param_grid_dt, cv=3, scoring='neg_mean_squared_error', n_jobs=-1)
grid_dt.fit(X_train.drop(columns=['signalDate']), y_train)

grid_gb = GridSearchCV(estimator=BaggingRegressor(base_estimator=GradientBoostingRegressor(), random_state=42),
                       param_grid=param_grid_gb, cv=3, scoring='neg_mean_squared_error', n_jobs=-1)
grid_gb.fit(X_train.drop(columns=['signalDate']), y_train)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# ...

# %%
# Function to calculate percentage error
def calculate_percentage_error(true_values, predictions):
    return np.abs((true_values - predictions) / true_values) * 100

# %%
# Predictions with the best models
lr_bagging_predictions = grid_lr.predict(X_validation.drop(columns=['signalDate']))
dt_bagging_predictions = grid_dt.predict(X_validation.drop(columns=['signalDate']))
gb_bagging_predictions = grid_gb.predict(X_validation.drop(columns=['signalDate']))

# %%
# RMSE for the best models
lr_bagging_rmse = calculate_rmse(y_validation, lr_bagging_predictions)
dt_bagging_rmse = calculate_rmse(y_validation, dt_bagging_predictions)
gb_bagging_rmse = calculate_rmse(y_validation, gb_bagging_predictions)

# %%
# Calculate percentage error for the best models
lr_bagging_percentage_error = calculate_percentage_error(y_validation, lr_bagging_predictions)
dt_bagging_percentage_error = calculate_percentage_error(y_validation, dt_bagging_predictions)
gb_bagging_percentage_error = calculate_percentage_error(y_validation, gb_bagging_predictions)

# %%
print(f"Bagging Linear Regression RMSE: {lr_bagging_rmse:.4f}")
print(f"Bagging Decision Tree RMSE: {dt_bagging_rmse:.4f}")
print(f"Bagging Gradient Boosting RMSE: {gb_bagging_rmse:.4f}")



print(f"Bagging Linear Regression Mean Percentage Error: {lr_bagging_percentage_error.mean():.4f}%")
print(f"Bagging Decision Tree Mean Percentage Error: {dt_bagging_percentage_error.mean():.4f}%")
print(f"Bagging Gradient Boosting Mean Percentage Error: {gb_bagging_percentage_error.mean():.4f}%")
# Out:
# Bagging Linear Regression RMSE: 9.7782
# Bagging Decision Tree RMSE: 16.1681
# Bagging Gradient Boosting RMSE: 11.1184
# Bagging Linear Regression Mean Percentage Error: 0.6555%
# Bagging Decision Tree Mean Percentage Error: 0.8543%
# Bagging Gradient Boosting Mean Percentage Error: 0.6631%

# %%
# Dataframes for predicted values with signalDate
validation_predictions_df = pd.DataFrame({
    'signalDate': X_validation_with_date['signalDate'],
    'Actual': y_validation,
    'Bagging_LR': lr_bagging_predictions,
    'Bagging_DT': dt_bagging_predictions,
    'Bagging_GB': gb_bagging_predictions
}, index=y_validation.index)

validation_predictions_df
# Out:
#     signalDate   Actual   Bagging_LR  Bagging_DT   Bagging_GB
# 765 2024-03-01  1408.15  1399.698846    1400.387  1398.439141
# 766 2024-03-03  1386.35  1373.280994    1384.324  1384.389963
# 767 2024-03-04  1388.45  1379.147663    1394.283  1390.402258
# 768 2024-03-05  1374.20  1370.550892    1395.816  1382.087785
# 769 2024-03-06  1363.55  1349.735754    1388.549  1371.919077
# 770 2024-03-10  1367.85  1355.445019    1390.710  1375.939167
# 771 2024-03-11  1337.20  1324.691200    1381.367  1361.505578
# 772 2024-03-12  1308.65  1296.412820    1332.150  1323.484808
# 773 2024-03-13  1329.00  1323.768147    1332.720  1330.675049
# 774 2024-03-14  1341.45  1341.450826    1332.287  1330.483383
# 775 2024-03-17  1337.20  1336.119184    1332.775  1330.221874
# 776 2024-03-18  1337.10  1338.731722    1334.751  1337.286072
# 777 2024-03-19  1325.25  1319.976014    1328.316  1329.157270
# 778 2024-03-20  1317.80  1306.944932    1320.224  1319.514022
# ...

# %%
plt.figure(figsize=(14, 7))
plt.plot(validation_predictions_df['signalDate'], validation_predictions_df['Actual'], label='Actual', color='blue')
plt.plot(validation_predictions_df['signalDate'], validation_predictions_df['Bagging_LR'], label='Bagging Linear Regression', color='red')
plt.plot(validation_predictions_df['signalDate'], validation_predictions_df['Bagging_DT'], label='Bagging Decision Tree', color='green')
plt.plot(validation_predictions_df['signalDate'], validation_predictions_df['Bagging_GB'], label='Bagging Gradient Boosting', color='orange')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.title('Actual vs Predicted Close Prices (Validation Set)')
plt.legend()
plt.show()

# %%
import pandas as pd
from IPython.display import HTML
import base64

file_path = 'validation_predictions.csv'
validation_predictions_df.to_csv(file_path, index=False)

def create_download_link(file_path, file_name):
    with open(file_path, 'rb') as f:
        data = f.read()
    b64 = base64.b64encode(data).decode()
    href = f'<a href="data:file/csv;base64,{b64}" download="{file_name}">Download CSV file</a>'
    return HTML(href)

create_download_link(file_path, 'validation_predictions.csv')
# Out:
# <a href="data:file/csv;base64,..." download="validation_predictions.csv">Download CSV file</a>

# %%
import pymongo
from pymongo import MongoClient

client = MongoClient('mongodb://intelliinvest:intelliinvest@67.211.219.52:27017/intelliinvest')
db = client['intelliinvest']
collection = db['STOCK_FUNDAMENTALS']

distinct_security_ids = collection.distinct("securityId")

for security_id in distinct_security_ids:
    print(security_id)

# If you want to see how many distinct securityIds are there
print(f"Total distinct securityIds: {len(distinct_security_ids)}")
# Out:
# 20MICRONS
# 21STCENMGM
# 360ONE
# 3IINFOLTD
# 3MINDIA
# 3PLAND
# 4THDIM
# 4THGEN
# 500033
# 500084
# 500163
# 500170
# 500285
# 500331
# 500338
# 500339
# 500355
# 500380
# 500390
# 500429
# 500464
# 500940
# 501343
# 502090
# 502448
# 502986
# 503722
# 504067
# 505200
# 505255
# 505509
# 505726
# 505790
# 505800
# 505890
# 506146
# 506690
# 507490
# 507828
# 507878
# 507880
# 509055
# 509220
# 511726
# 512626
# 513121
# 513683
# 514043
# 514162
# 516072
# 516082
# 519126
# 519307
# 519494
# 519552
# 520113
# 522205
# 523261
# 523384
# 523539
# 523642
# 523756
# 524051
# 524200
# 524226
# 524570
# 524667
# 524689
# 524709
# 526227
# 526247
# 526381
# 526582
# 526947
# 530001
# 530377
# 530517
# 531349
# 531381
# 531518
# 532123
# 532163
# 532300
# 532369
# 532370
# 532387
# 532482
# 532486
# 532497
# 532524
# 532527
# 532605
# 532628
# 532648
# 532670
# 532693
# 532698
# 532699
# 532705
# 532708
# 532727
# 532734
# 532744
# 532759
# 532780
# 532805
# 532813
# 532826
# 532850
# ...
