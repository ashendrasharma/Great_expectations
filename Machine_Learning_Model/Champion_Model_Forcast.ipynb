# %%
import pandas as pd
import pymongo
from pymongo import MongoClient

client = MongoClient('mongodb://intelliinvest:intelliinvest@67.211.219.52:27017/intelliinvest')
db = client['intelliinvest']
collection = db['STOCK_PRICE_FORECAST_2']

security_id = "INDIGOPNTS"
query = {"securityId": security_id}
results = collection.find(query).limit(5000)

TCS = pd.DataFrame(list(results))
TCS
# Out:
#                           _id  securityId           todayDate  todayPrice  \
# 0    6637118af3404e7597b21ad9  INDIGOPNTS 2021-02-01 18:30:00     3104.49
# 1    6637118af3404e7597b21ada  INDIGOPNTS 2021-02-02 18:30:00     2912.37
# 2    6637118af3404e7597b21adc  INDIGOPNTS 2021-02-04 18:30:00     2619.37
# 3    6637118af3404e7597b21adb  INDIGOPNTS 2021-02-03 18:30:00     2862.08
# 4    6637118af3404e7597b21add  INDIGOPNTS 2021-02-07 18:30:00     2666.18
# ..                        ...         ...                 ...         ...
# 810  664344ee0c35f0217ac2b763  INDIGOPNTS 2024-05-13 18:30:00     1360.00
# 811  664555720c35f0217a048368  INDIGOPNTS 2024-05-14 18:30:00     1354.75
# 812  664555720c35f0217a048369  INDIGOPNTS 2024-05-15 18:30:00     1354.75
# 813  664555ba0c35f0217a04b9f8  INDIGOPNTS 2024-05-15 18:30:00     1354.75
# 814  664555ba0c35f0217a04b9f7  INDIGOPNTS 2024-05-14 18:30:00     1354.75
#
#     tomorrowForecastDate  tomorrowActualPrice  weeklyForecastDate  \
# ...

# %%
TCS = TCS.rename(columns={'todayDate': 'signalDate'})
print(TCS.columns)
# Out:
# Index(['_id', 'securityId', 'signalDate', 'todayPrice', 'tomorrowForecastDate',
#        'tomorrowActualPrice', 'weeklyForecastDate', 'weeklyActualPrice',
#        'monthlyForecastDate', 'monthlyActualPrice', '_class',
#        'tomorrowForecastPrice', 'weeklyForecastPrice', 'monthlyForecastPrice'],
#       dtype='object')

# %%
TCS['signalDate'] = pd.to_datetime(TCS['signalDate'])
TCS['tomorrowForecastDate'] = pd.to_datetime(TCS['tomorrowForecastDate'])

# %%
TCS['signalDate'] = pd.to_datetime(TCS['signalDate'])
TCS['signalDate'] = TCS['signalDate'].dt.date
print(TCS['signalDate'])
# Out:
# 0      2021-02-01
# 1      2021-02-02
# 2      2021-02-04
# 3      2021-02-03
# 4      2021-02-07
#           ...
# 810    2024-05-13
# 811    2024-05-14
# 812    2024-05-15
# 813    2024-05-15
# 814    2024-05-14
# Name: signalDate, Length: 815, dtype: object

# %%
TCS['tomorrowForecastDate'] = pd.to_datetime(TCS['tomorrowForecastDate'])
TCS['tomorrowForecastDate'] = TCS['tomorrowForecastDate'].dt.date
print(TCS['tomorrowForecastDate'])
# Out:
# 0      2021-02-02
# 1      2021-02-03
# 2      2021-02-07
# 3      2021-02-04
# 4      2021-02-08
#           ...
# 810    2024-05-14
# 811    2024-05-15
# 812    2024-05-16
# 813    2024-05-16
# 814    2024-05-15
# Name: tomorrowForecastDate, Length: 815, dtype: object

# %%
TCS['signalDate'] = pd.to_datetime(TCS['signalDate'])

# Filter for rows where the 'signalDate' is in March 2024
march_2024_data = TCS[(TCS['signalDate'].dt.year == 2024) & (TCS['signalDate'].dt.month == 3)]
march_2024_data
# Out:
#                           _id  securityId signalDate  todayPrice  \
# 763  6637118af3404e7597b21dd6  INDIGOPNTS 2024-03-03     1386.35
# 764  6637118af3404e7597b21dd7  INDIGOPNTS 2024-03-04     1388.45
# 765  6637118af3404e7597b21dd8  INDIGOPNTS 2024-03-05     1374.20
# 766  6637118af3404e7597b21dd9  INDIGOPNTS 2024-03-06     1363.55
# 767  6637118af3404e7597b21dda  INDIGOPNTS 2024-03-10     1367.85
# 769  6637118af3404e7597b21ddc  INDIGOPNTS 2024-03-12     1308.65
# 770  6637118af3404e7597b21ddd  INDIGOPNTS 2024-03-13     1329.00
# 771  6637118af3404e7597b21ddf  INDIGOPNTS 2024-03-17     1337.20
# 772  6637118af3404e7597b21dde  INDIGOPNTS 2024-03-14     1341.45
# 773  6637118af3404e7597b21de0  INDIGOPNTS 2024-03-18     1337.10
# 774  6637118af3404e7597b21ddb  INDIGOPNTS 2024-03-11     1337.20
# 775  6637118af3404e7597b21de1  INDIGOPNTS 2024-03-19     1325.25
# 777  6637118af3404e7597b21de2  INDIGOPNTS 2024-03-20     1317.80
# ...

# %%
march_2024_03 = march_2024_data[['tomorrowForecastDate', 'tomorrowActualPrice','tomorrowForecastPrice']]
march_2024_03
# Out:
#     tomorrowForecastDate  tomorrowActualPrice  tomorrowForecastPrice
# 763           2024-03-04              1388.45            1420.632589
# 764           2024-03-05              1374.20            1436.636270
# 765           2024-03-06              1363.55            1449.431703
# 766           2024-03-10              1367.85            1446.634014
# 767           2024-03-11              1337.20            1402.788396
# 769           2024-03-13              1329.00            1381.489039
# 770           2024-03-14              1341.45            1407.442561
# 771           2024-03-18              1337.10            1359.670584
# 772           2024-03-17              1337.20            1418.191761
# 773           2024-03-19              1325.25            1369.794178
# 774           2024-03-12              1308.65            1392.570963
# 775           2024-03-20              1317.80            1360.214492
# 777           2024-03-21              1321.20            1360.823030
# ...

# %%
import pandas as pd
from IPython.display import HTML
import base64

file_path = 'march_2024_03.csv'
march_2024_03.to_csv(file_path, index=False)

# %%
def create_download_link(file_path, file_name):
    with open(file_path, 'rb') as f:
        data = f.read()
    b64 = base64.b64encode(data).decode()
    href = f'<a href="data:file/csv;base64,{b64}" download="{file_name}">Download CSV file</a>'
    return HTML(href)

create_download_link(file_path, 'march_2024_03.csv')
# Out:
# <a href="data:file/csv;base64,..." download="march_2024_03.csv">Download CSV file</a>
